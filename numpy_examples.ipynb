# %%
numpy
=====

# %%
L=[10,20,30]  # List - collection of items(different type)
L+100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 L=[10,20,30]  # List - collection of items(different type)
# ----> 2 L+100
#
# TypeError: can only concatenate list (not "int") to list

# %%
L1=[1,2,3,4]
L2=[5,6,7,8]
L1+L2
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
import array
array.array('i',[1,2,3])
# Out:
# array('i', [1, 2, 3])

# %%
a1=array.array('i',[1,2,3])
a1[0]
# Out:
# 1

# %%
a1[1]
# Out:
# 2

# %%
a1.append(40)
a1
# Out:
# array('i', [1, 2, 3, 40])

# %%
a1.append('data')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a1.append('data')
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
a1.append(2.6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a1.append(2.6)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
a1= array.array('i',[1,2,3])
a2=array.array('i',[10,20,30])
a1+a2 # Like List concatenate
# Out:
# array('i', [1, 2, 3, 10, 20, 30])

# %%
python.org--> python + std libraries 
--------------------------------------------> pip install numpy

# %%
import numpy

# numpy array index, slicing, shape, reshape,dim
# numpy functions

# %%
numpy.array([10,20,30])
# Out:
# array([10, 20, 30])

# %%
numpy.array([10,20,30,40.0])
# Out:
# array([10., 20., 30., 40.])

# %%
numpy.array([10,20,30,'data',True])
# Out:
# array(['10', '20', '30', 'data', 'True'], dtype='<U21')

# %%
numpy.array([10,20,30,True,False])
# Out:
# array([10, 20, 30,  1,  0])

# %%
arr=numpy.array([10,20,30])
arr+ 100
# Out:
# array([110, 120, 130])

# %%
arr=numpy.array([10,20,30])
arr*0.12
# Out:
# array([1.2, 2.4, 3.6])

# %%
arr1=numpy.array([10,20,30])
arr2=numpy.array([100,200,300])
arr1+arr2
# Out:
# array([110, 220, 330])

# %%
arr1=numpy.array([10,20,30])
arr2=numpy.array([100,200,300])
print(arr1 + arr2)
print(arr1 - arr2)
print(arr1 * arr2)
print(arr1 / 5)
print(arr1 ** 2)
# Out:
# [110 220 330]
# [ -90 -180 -270]
# [1000 4000 9000]
# [2. 4. 6.]
# [100 400 900]

# %%
numpy.array([10,20,30]) +100
# Out:
# array([110, 120, 130])

# %%
numpy.array([10,20,30]) + numpy.array([10,20,30,40])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 numpy.array([10,20,30]) + numpy.array([10,20,30,40])
#
# ValueError: operands could not be broadcast together with shapes (3,) (4,)

# %%
numpy.array([10,20,30,40]) < numpy.array([100,200,300,400])
# Out:
# array([ True,  True,  True,  True])

# %%
numpy.array([10,20,30,40]) > numpy.array([100,200,300,400])
# Out:
# array([False, False, False, False])

# %%
numpy.array([10,20,30,40]) > 35
# Out:
# array([False, False, False,  True])

# %%
import array
array.array('i',[1,2,3,4])  # single dim
# Out:
# array('i', [1, 2, 3, 4])

# %%
array.array('i',[[1,2,3,4]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 array.array('i',[[1,2,3,4]])
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
import numpy
numpy.array([[1,2,3,4]])
# Out:
# array([[1, 2, 3, 4]])

# %%
arr1=numpy.array([1,2,3,4])
arr2=numpy.array([[100,200,300,400]])
print(arr1,arr2)
print(arr1.ndim, arr2.ndim)
# Out:
# [1 2 3 4] [[100 200 300 400]]
# 1 2

# %%
arr2=numpy.array([[[100,200,300,400]]])
print(arr2)
print(arr2.ndim)
# Out:
# [[[100 200 300 400]]]
# 3

# %%
numpy.array([[[[[[[[[[]]]]]]]]]]).ndim
# Out:
# 10

# %%
#shape -> tuple(rows,cols)

a1= numpy.array([10,20,30,40])   
a2= numpy.array([[10,20,30,40]])   
a3= numpy.array([[[10,20,30,40]]]) 
print(a1.shape)
print(a2.shape)
print(a3.shape)
# Out:
# (4,)
# (1, 4)
# (1, 1, 4)

# %%
#|col1||col2|....|coln|-> R1||  R2

# %%
a3= numpy.array([[[10,20,30],[40,50,60]]]) 
print(a3.ndim,a3.shape)
# Out:
# 3 (1, 2, 3)

# %%
a3= numpy.array([[[10,20,30],[40,50,60],[70,10,20],[40,90,1]]]) 
print(a3.ndim,a3.shape)
# Out:
# 3 (1, 4, 3)

# %%
a3= numpy.array([[[10,20,30],[40,50,60],[70,10,20],[40,90,1]]]) 
print(a3[0])
# Out:
# [[10 20 30]
#  [40 50 60]
#  [70 10 20]
#  [40 90  1]]

# %%
a3= numpy.array([[[10,20,30],[40,50,60],[70,10,20],[40,90,1]]]) 
print(a3[0][0])
# Out:
# [10 20 30]

# %%
a3= numpy.array([[[10,20,30],[40,50,60],[70,10,20],[40,90,1]]]) 
print(a3[0][0][0])
# Out:
# 10

# %%
a3= numpy.array([[[10,20,30],[40,50,60],[70,10,20],[40,90,1]]]) 
print(a3[0][0][0])
print(a3[0][0][1])
print(a3[0][0][-1])
# Out:
# 10
# 20
# 30

# %%
print(a3[0][1])
# Out:
# [40 50 60]

# %%
print(a3[0][1][0])
# Out:
# 40

# %%
range(5)
# Out:
# range(0, 5)

# %%
import numpy as np
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
np.random.rand()
# Out:
# 0.4792917105212193

# %%
np.random.randint(10)
# Out:
# 6

# %%
np.random.randint(5,15,3)  #any 3 random nos
# Out:
# array([11,  7, 14], dtype=int32)

# %%
np.zeros(5) # generate 1 dim array with zeros
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.ones(5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
np.asarray([10,20,30], dtype=float)
# Out:
# array([10., 20., 30.])

# %%
a1= np.array([[10,20,30],[40,50,60]])
print(type(a1))
print(a1.ndim)
print(a1.shape)
# Out:
# <class 'numpy.ndarray'>
# 2
# (2, 3)

# %%
np.asarray([[10,20,30],[40,50,60]],dtype=float)
# Out:
# array([[10., 20., 30.],
#        [40., 50., 60.]])

# %%
a1= np.array([[10,20,30],[40,50,60]])
np.reshape(a1,(3,2))
# Out:
# array([[10, 20],
#        [30, 40],
#        [50, 60]])

# %%
np.add(a1,a2)  --> np.a1 +np.a2
np.less(a1,a2)  -->  np.a1  < np.a2
np.greater(a1,a2)  --> np.a1 > np.a2

# %%
# statistical functions
np.median()
np.mean()
np.std()

# %%
np.median([10,20,30,4,40,50,60])
# Out:
# np.float64(30.0)

# %%
np.mean([10,20,30,4,40,50,60])
# Out:
# np.float64(30.571428571428573)

# %%
a2=np.array([[10,20,30],[40,50,60]])
a2.ndim
# Out:
# 2

# %%
a2.flatten()
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
a2.dtype
# Out:
# dtype('int64')

# %%
np.array([10,20,30.0]).dtype
# Out:
# dtype('float64')

# %%
np.array([10,20,'30.0']).dtype
# Out:
# dtype('<U21')

# %%
np.array([10,20,True,False]).dtype
# Out:
# dtype('int64')

# %%
np.array([True,False]).dtype
# Out:
# dtype('bool')

# %%
print(np.array([10,20,30]))  # int32/64
# vs
np.array([10,20,30],dtype='float')
# Out:
# [10 20 30]
# array([10., 20., 30.])
